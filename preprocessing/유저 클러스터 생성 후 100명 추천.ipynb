# %%
dev_users = []
path1 = '/Volumes/Seoin Baek/브런치 사용자를 위한 글 추천 대회/res/predict/dev.users.txt'
with open(path1,'r') as dev:
    for line in dev:
        line = line.rstrip()
        dev_users.append(line)

# %%
test_users = []
path2 = '/Volumes/Seoin Baek/브런치 사용자를 위한 글 추천 대회/res/predict/test.users.txt'
with open(path2,'r') as test:
    for line in test:
        line = line.rstrip()
        test_users.append(line)
print(len(test_users))
# Out:
# 5000

# %%
import json
import ujson
from pprint import pprint

USER = dict()
check = dict()
if __name__ == "__main__":
    file_path = '/Volumes/Seoin Baek/브런치 사용자를 위한 글 추천 대회/res/user_json2.txt'
    with open(file_path,'r') as file_name:
        for users in file_name:
            users = ujson.loads(users)
            for key, values in users.items():
                if key in test_users:
                    for k,v in values.items():
                        try:
                            USER[key][k] = "1"
                        except:
                            USER[key] = dict()
                            USER[key][k] = "1"
                        try:
                            check[k] +=v
                        except:
                            check[k] = 0
                            check[k] +=v

# %%
for i in test_users:
    if i not in USER:
        i = i.rstrip()
        USER[i] = dict()

# %%
print(len(USER))
# Out:
# 5000

# %%
if __name__ == "__main__":
    file_path = '/Volumes/Seoin Baek/브런치 사용자를 위한 글 추천 대회/res/user_json2.txt'
    with open(file_path,'r') as file_name:
        for users in file_name:
            users = ujson.loads(users)
            for key, values in users.items():
                if key not in test_users:
                    for k,v in values.items():
                        try:
                            USER[key][k] = "1"
                        except:
                            USER[key] = dict()
                            USER[key][k] = "1"
                        try:
                            check[k] +=v
                        except:
                            check[k] = 0
                            check[k] +=v
                        if len(USER) >= 50000:
                            break
                    if len(USER) >= 50000:
                            break
                if len(USER) >= 50000:
                            break

# %%
USER2 = dict()
for x,y in USER.items():
    USER2[x] = dict()
    for z,g in y.items():
        if check[z] <100:
            continue
        else:
            try:
                USER2[x][z] = g
            except:
                USER2[x]=dict()
                USER2[x][z] = g

# %%
print(len(USER2))
# Out:
# 50000

# %%
#넘어가기
if __name__ == "__main__":
    file_path = '/Volumes/Seoin Baek/브런치 사용자를 위한 글 추천 대회/res/user_json.txt'
    with open(file_path,'r') as file_name:
        for users in file_name:
            users = ujson.loads(users)
            for key, values in users.items():
                if key not in test_users:
                    for k,v in values.items():
                        try:
                            USER[key][k] = "v"
                        except:
                            USER[key] = dict()
                            USER[key][k] = "v"
                        if len(USER) >= 20000:
                            break
                    if len(USER) >= 20000:
                            break
                if len(USER) >= 20000:
                            break

# %%
import pandas as pd
df = pd.DataFrame(USER2)
df =df.fillna(value = "0")
df = df.T

# %%
df.columns
# Out:
# Index(['@01026856762_102', '@01038273527_16', '@01038273527_17',
#        '@01038273527_20', '@01038273527_21', '@01038273527_23',
#        '@01038273527_28', '@01038273527_34', '@01038273527_36',
#        '@01038273527_44',
#        ...
#        '@zeustyle_3', '@zeustyle_4', '@zigzag_11', '@zirimnet_13',
#        '@zolbi1127_3', '@zorbayoun_30', '@zzolmarkb6sm_199',
#        '@zzolmarkb6sm_219', '@zzolmarkb6sm_221', '@zzongali_117'],
#       dtype='object', length=3113)

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_points = df.values

# %%
kmeans = KMeans(n_clusters=30).fit(data_points)

# %%
kmeans.labels_
# Out:
# array([25,  2,  6, ...,  4, 23,  4], dtype=int32)

# %%
df['cluster_id'] = kmeans.labels_

# %%
df.head(20)
# Out:
#                                   @01026856762_102 @01038273527_16  \
# #83085e65f7e97b0067c63e246133fe5c                0               0
# #0074f661772d7539392deb072c28c651                0               0
# #2fa2fce3e5e925a5dd325796d3260dbd                0               0
# #38a8b6e043685216c1240cddf481e6b4                0               0
# #912f9cd74d719e804c7d47b60a001442                0               0
# #652faee04802e55d67efd82a369c3913                0               0
# #27cdb299806bc26a03882d7be30d4092                0               0
# #1118aaecc582d18f4844772da32a4370                0               0
# #479ad1cd5554d3c4a96ee8f8ccee2c61                0               0
# #0204e5ddd7114420601893afd9edf494                0               0
# #32a4d0268ccc02ad1e596d7c99893eed                0               0
# #20bf2c621d64921c4e22c99e39775f5a                0               0
# #63ed3b7a86e1715dd2a34b588b7380af                0               0
# ...

# %%
df2 = df["cluster_id"]

# %%
cluster0 = {}
cluster1 = {}
cluster2 = {}
cluster3= {}
cluster4 = {}
cluster5 = {}
cluster6 = {}
cluster7 = {}
cluster8 = {}
cluster9 = {}
cluster10 = {}
cluster11 = {}
cluster12 = {}
cluster13= {}
cluster14 = {}
cluster15 = {}
cluster16 = {}
cluster17 = {}
cluster18 = {}
cluster19 = {}
cluster20 = {}
cluster21 = {}
cluster22 = {}
cluster23= {}
cluster24 = {}
cluster25 = {}
cluster26 = {}
cluster27 = {}
cluster28 = {}
cluster29 = {}

# %%
path3 = '/Volumes/Seoin Baek/브런치 사용자를 위한 글 추천 대회/res/user_json2.txt'

read = {}
with open(path3,'r') as F:
    for x in F:
        x = ujson.loads(x)
        for k,v in x.items():
            read[k] = v

# %%
cluster_check = {}
for i,j in zip(USER2,df2):
    try:
        R = read[i]
    except:
        continue
    if j == 0:
        for K,V in R.items():
            try:
                cluster0[K] +=V
            except:
                cluster0[K] =0
                cluster0[K] +=V
    if j == 1:
        for K,V in R.items():
            try:
                cluster1[K] +=V
            except:
                cluster1[K] =0
                cluster1[K] +=V
    if j == 2:
        for K,V in R.items():
            try:
                cluster2[K] +=V
            except:
                cluster2[K] =0
                cluster2[K] +=V
    if j == 3:
        for K,V in R.items():
            try:
                cluster3[K] +=V
            except:
                cluster3[K] =0
                cluster3[K] +=V
    if j == 4:
        for K,V in R.items():
            try:
                cluster4[K] +=V
            except:
                cluster4[K] =0
                cluster4[K] +=V
    if j == 5:
        for K,V in R.items():
            try:
                cluster5[K] +=V
            except:
                cluster5[K] =0
                cluster5[K] +=V
    if j == 6:
        for K,V in R.items():
            try:
                cluster6[K] +=V
            except:
                cluster6[K] =0
                cluster6[K] +=V
    if j == 7:
        for K,V in R.items():
            try:
                cluster7[K] +=V
            except:
                cluster7[K] =0
                cluster7[K] +=V
    if j == 8:
        for K,V in R.items():
            try:
                cluster8[K] +=V
            except:
                cluster8[K] =0
                cluster8[K] +=V
    if j == 9:
        for K,V in R.items():
            try:
                cluster9[K] +=V
            except:
                cluster9[K] =0
                cluster9[K] +=V
    if j == 10:
        for K,V in R.items():
            try:
                cluster10[K] +=V
            except:
                cluster10[K] =0
                cluster10[K] +=V
    if j == 11:
        for K,V in R.items():
            try:
                cluster11[K] +=V
            except:
                cluster11[K] =0
                cluster11[K] +=V
    if j == 12:
        for K,V in R.items():
            try:
                cluster12[K] +=V
            except:
                cluster12[K] =0
                cluster12[K] +=V
    if j == 13:
        for K,V in R.items():
            try:
                cluster13[K] +=V
            except:
                cluster13[K] =0
                cluster13[K] +=V
    if j == 14:
        for K,V in R.items():
            try:
                cluster14[K] +=V
            except:
                cluster14[K] =0
                cluster14[K] +=V
    if j == 15:
        for K,V in R.items():
            try:
                cluster15[K] +=V
            except:
                cluster15[K] =0
                cluster15[K] +=V
    if j ==16:
        for K,V in R.items():
            try:
                cluster16[K] +=V
            except:
                cluster16[K] =0
                cluster16[K] +=V
    if j == 17:
        for K,V in R.items():
            try:
                cluster17[K] +=V
            except:
                cluster17[K] =0
                cluster17[K] +=V
    if j == 18:
        for K,V in R.items():
            try:
                cluster18[K] +=V
            except:
                cluster18[K] =0
                cluster18[K] +=V
    if j == 19:
        for K,V in R.items():
            try:
                cluster19[K] +=V
            except:
                cluster19[K] =0
                cluster19[K] +=V
    if j == 20:
        for K,V in R.items():
            try:
                cluster20[K] +=V
            except:
                cluster20[K] =0
                cluster20[K] +=V
    if j == 21:
        for K,V in R.items():
            try:
                cluster21[K] +=V
            except:
                cluster21[K] =0
                cluster21[K] +=V
    if j == 22:
        for K,V in R.items():
            try:
                cluster22[K] +=V
            except:
                cluster22[K] =0
                cluster22[K] +=V
    if j == 23:
        for K,V in R.items():
            try:
                cluster23[K] +=V
            except:
                cluster23[K] =0
                cluster23[K] +=V
    if j == 24:
        for K,V in R.items():
            try:
                cluster24[K] +=V
            except:
                cluster24[K] =0
                cluster24[K] +=V
    if j == 25:
        for K,V in R.items():
            try:
                cluster25[K] +=V
            except:
                cluster25[K] =0
                cluster25[K] +=V
    if j ==26:
        for K,V in R.items():
            try:
                cluster26[K] +=V
            except:
                cluster26[K] =0
                cluster26[K] +=V
    if j == 27:
        for K,V in R.items():
            try:
                cluster27[K] +=V
            except:
                cluster27[K] =0
                cluster27[K] +=V
    if j == 28:
        for K,V in R.items():
            try:
                cluster28[K] +=V
            except:
                cluster28[K] =0
                cluster28[K] +=V
    if j == 29:
        for K,V in R.items():
            try:
                cluster29[K] +=V
            except:
                cluster29[K] =0
                cluster29[K] +=V

    cluster_check[i] = j

# %%
#print(sorted(cluster0.items(), reverse = True))
C0 = sorted(cluster0, key=lambda k : cluster0[k], reverse=True)
C1 = sorted(cluster1, key=lambda k : cluster1[k], reverse=True)
C2 = sorted(cluster2, key=lambda k : cluster2[k], reverse=True)
C3 = sorted(cluster3, key=lambda k : cluster3[k], reverse=True)
C4 = sorted(cluster4, key=lambda k : cluster4[k], reverse=True)
C5 = sorted(cluster5, key=lambda k : cluster5[k], reverse=True)
C6 = sorted(cluster6, key=lambda k : cluster6[k], reverse=True)
C7 = sorted(cluster7, key=lambda k : cluster7[k], reverse=True)
C8 = sorted(cluster8, key=lambda k : cluster8[k], reverse=True)
C9 = sorted(cluster9, key=lambda k : cluster9[k], reverse=True)
C10 = sorted(cluster10, key=lambda k : cluster10[k], reverse=True)
C11 = sorted(cluster11, key=lambda k : cluster11[k], reverse=True)
C12 = sorted(cluster12, key=lambda k : cluster12[k], reverse=True)
C13 = sorted(cluster13, key=lambda k : cluster13[k], reverse=True)
C14 = sorted(cluster14, key=lambda k : cluster14[k], reverse=True)
C15 = sorted(cluster15, key=lambda k : cluster15[k], reverse=True)
C16 = sorted(cluster16, key=lambda k : cluster16[k], reverse=True)
C17 = sorted(cluster17, key=lambda k : cluster17[k], reverse=True)
C18 = sorted(cluster18, key=lambda k : cluster18[k], reverse=True)
C19 = sorted(cluster19, key=lambda k : cluster19[k], reverse=True)
C20 = sorted(cluster20, key=lambda k : cluster20[k], reverse=True)
C21 = sorted(cluster21, key=lambda k : cluster21[k], reverse=True)
C22 = sorted(cluster22, key=lambda k : cluster22[k], reverse=True)
C23 = sorted(cluster23, key=lambda k : cluster23[k], reverse=True)
C24 = sorted(cluster24, key=lambda k : cluster24[k], reverse=True)
C25 = sorted(cluster25, key=lambda k : cluster25[k], reverse=True)
C26 = sorted(cluster26, key=lambda k : cluster26[k], reverse=True)
C27 = sorted(cluster27, key=lambda k : cluster27[k], reverse=True)
C28 = sorted(cluster28, key=lambda k : cluster28[k], reverse=True)
C29 = sorted(cluster29, key=lambda k : cluster29[k], reverse=True)
print(len(C0))
print(len(C1))
print(len(C2))
print(len(C3))
print(len(C4))
print(len(C5))
print(len(C6))
print(len(C7))
print(len(C8))
print(len(C9))
print(len(C10))
print(len(C11))
print(len(C12))
print(len(C13))
print(len(C14))
print(len(C15))
print(len(C16))
print(len(C17))
print(len(C18))
print(len(C19))
print(len(C20))
print(len(C21))
print(len(C22))
print(len(C23))
print(len(C24))
print(len(C25))
print(len(C26))
print(len(C27))
print(len(C28))
print(len(C29))
# Out:
# 203
# 67171
# 47915
# 10545
# 87538
# 696
# 7898
# 3233
# 6242
# 360
# 549
# 659
# 287
# 7568
# 18287
# 3972
# 20954
# 828
# 15851
# 1629
# 4290
# 5983
# 149
# 24510
# 496
# 29745
# 7619
# 12734
# 438
# 2594

# %%
print(len(cluster_check))
# Out:
# 50000

# %%
def Write(output_file_name,text):        
    
    with open(output_file_name, "w", encoding="utf-8") as output_file:
        print(text, file=output_file, end=' ')
        
output_file_name = r"/Volumes/Seoin Baek/브런치 사용자를 위한 글 추천 대회/res/recommend.txt"

with open(output_file_name, "w", encoding="utf-8") as output_file:
    for dev in dev_users:
        a = cluster_check[dev]
        List = []
        if a == 0:
            print(dev, file=output_file, end=' ')
            for i in C0:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 1:
            print(dev, file=output_file, end=' ')
            for i in C1:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 2:
            print(dev, file=output_file, end=' ')
            for i in C2:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 3:
            print(dev, file=output_file, end=' ')
            for i in C3:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 4:
            print(dev, file=output_file, end=' ')
            for i in C4:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 5:
            print(dev, file=output_file, end=' ')
            for i in C5:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 6:
            print(dev, file=output_file, end=' ')
            for i in C6:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 7:
            print(dev, file=output_file, end=' ')
            for i in C7:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 8:
            print(dev, file=output_file, end=' ')
            for i in C8:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 9:
            print(dev, file=output_file, end=' ')
            for i in C9:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 10:
            print(dev, file=output_file, end=' ')
            for i in C10:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 11:
            print(dev, file=output_file, end=' ')
            for i in C11:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 12:
            print(dev, file=output_file, end=' ')
            for i in C12:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 13:
            print(dev, file=output_file, end=' ')
            for i in C13:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 14:
            print(dev, file=output_file, end=' ')
            for i in C14:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 15:
            print(dev, file=output_file, end=' ')
            for i in C15:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 16:
            print(dev, file=output_file, end=' ')
            for i in C16:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 17:
            print(dev, file=output_file, end=' ')
            for i in C17:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 18:
            print(dev, file=output_file, end=' ')
            for i in C18:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 19:
            print(dev, file=output_file, end=' ')
            for i in C19:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 20:
            print(dev, file=output_file, end=' ')
            for i in C20:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 21:
            print(dev, file=output_file, end=' ')
            for i in C21:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 22:
            print(dev, file=output_file, end=' ')
            for i in C22:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 23:
            print(dev, file=output_file, end=' ')
            for i in C23:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 24:
            print(dev, file=output_file, end=' ')
            for i in C24:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 25:
            print(dev, file=output_file, end=' ')
            for i in C25:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 26:
            print(dev, file=output_file, end=' ')
            for i in C26:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 27:
            print(dev, file=output_file, end=' ')
            for i in C27:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 28:
            print(dev, file=output_file, end=' ')
            for i in C28:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
        if a == 29:
            print(dev, file=output_file, end=' ')
            for i in C29:
                if i not in USER2[dev]:
                    List.append(i)
                    if len(List) ==100:
                        for index, j in enumerate(List):
                            if index != 99:
                                print(j, file=output_file, end=' ')
                            else:
                                print(j,file=output_file)
                        break
            continue
